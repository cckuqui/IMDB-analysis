# %%
# Import libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# Import csv files
movies = pd.read_csv('IMDb_movies.csv')
actors = pd.read_csv('IMDb_names.csv')
ratings = pd.read_csv('IMDb_ratings.csv')
title_principals = pd.read_csv('IMDb_title_principals.csv')

# %%
movies = pd.DataFrame(movies)
actors = pd.DataFrame(actors)
ratings = pd.DataFrame(ratings)
title_principals = pd.DataFrame(title_principals)

# %%
movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
title_principals.columns
# Out:
# Index(['imdb_title_id', 'ordering', 'imdb_name_id', 'category', 'job',
#        'characters'],
#       dtype='object')

# %%
movies = pd.merge(movies,title_principals[['imdb_title_id', 'ordering', 'imdb_name_id', 'category', 'job',
       'characters']],on='imdb_title_id',how='left')
movies
# Out:
#        imdb_title_id                        title  \
# 0          tt0000574  The Story of the Kelly Gang
# 1          tt0000574  The Story of the Kelly Gang
# 2          tt0000574  The Story of the Kelly Gang
# 3          tt0000574  The Story of the Kelly Gang
# 4          tt0000574  The Story of the Kelly Gang
# ...              ...                          ...
# 420307     tt9903716                       Jessie
# 420308     tt9905412                        Ottam
# 420309     tt9905462                    Pengalila
# 420310     tt9911774    Padmavyuhathile Abhimanyu
# 420311     tt9914286            Sokagin Çocuklari
#
#                      original_title  year date_published  \
# 0       The Story of the Kelly Gang  1906     1906-12-26
# 1       The Story of the Kelly Gang  1906     1906-12-26
# 2       The Story of the Kelly Gang  1906     1906-12-26
# 3       The Story of the Kelly Gang  1906     1906-12-26
# 4       The Story of the Kelly Gang  1906     1906-12-26
# ...

# %%
movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'year', 'date_published', 'genre', 'country',
#        'language', 'director', 'writer', 'production_company', 'actors',
#        'avg_vote', 'votes', 'budget', 'usa_gross_income',
#        'worlwide_gross_income', 'metascore', 'ordering', 'imdb_name_id',
#        'category', 'job', 'characters'],
#       dtype='object')

# %%
ratings.columns
# Out:
# Index(['imdb_title_id', 'weighted_average_vote', 'total_votes', 'mean_vote',
#        'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6',
#        'votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1',
#        'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes', 'males_0age_avg_vote',
#        'males_0age_votes', 'males_18age_avg_vote', 'males_18age_votes',
#        'males_30age_avg_vote', 'males_30age_votes', 'males_45age_avg_vote',
#        'males_45age_votes', 'females_allages_avg_vote',
#        'females_allages_votes', 'females_0age_avg_vote', 'females_0age_votes',
#        'females_18age_avg_vote', 'females_18age_votes',
#        'females_30age_avg_vote', 'females_30age_votes',
# ...

# %%
movies = pd.merge(movies,ratings[['imdb_title_id', 'weighted_average_vote']],on='imdb_title_id',how='left')
movies
# Out:
# Empty DataFrame
# Columns: [title, year, date_published, genre, country, language, director, writer, production_company, actors, avg_vote, votes, budget, usa_gross_income, worlwide_gross_income, metascore, ordering, imdb_name_id, category, job, characters, weighted_average_vote_x, imdb_title_id, weighted_average_vote_y]
# Index: []
#
# [0 rows x 24 columns]

# %%
movies.columns
# Out:
# Index(['title', 'year', 'date_published', 'genre', 'country', 'language',
#        'director', 'writer', 'production_company', 'actors', 'avg_vote',
#        'votes', 'budget', 'usa_gross_income', 'worlwide_gross_income',
#        'metascore', 'ordering', 'imdb_name_id', 'category', 'job',
#        'characters', 'imdb_title_id', 'weighted_average_vote'],
#       dtype='object')

# %%
# Display preview of new columns
movies[['imdb_title_id','title','ordering','budget','usa_gross_income','worlwide_gross_income','avg_vote']]
# Out:
# Empty DataFrame
# Columns: [imdb_title_id, title, ordering, budget, usa_gross_income, worlwide_gross_income, avg_vote]
# Index: []

# %%
# DEPENDENCIES --------------------------------------------------------------
from scipy.stats import linregress

# CALCULATE VARIABLES--------------------------------------------------------
review_data_by_title = review_data.set_index(['title'])
ave_vote = review_data_by_title['avg_vote']
metascore = review_data_by_title['ordering']

# PLOT GRAPH-----------------------------------------------------------------
x_values = ave_vote
y_values = ordering
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,0),fontsize=12,color="red")
plt.title('Viewer Ratings vs. Production')
plt.xlabel('Av Vote')
plt.ylabel('Production size')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-75e1c8e1e1a7> in <module>
#       3
#       4 # CALCULATE VARIABLES--------------------------------------------------------
# ----> 5 review_data_by_title = review_data.set_index(['title'])
#       6 ave_vote = review_data_by_title['avg_vote']
#       7 metascore = review_data_by_title['ordering']
#
# NameError: name 'review_data' is not defined
